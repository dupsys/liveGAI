# %%
print("all okay")
# Out:
# all okay

# %%
import os
from dotenv import load_dotenv

# Get the path to the directory where the script is located
basedir = os.path.abspath(os.path.dirname("/Users/abbeydupe/Documents/dupe/liveGAI/env/"))
# Connect the path with your '.env' file name
dotenv_path = os.path.join(basedir, '.env')
load_dotenv(dotenv_path)
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY is missing in your .env")
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain_openai import ChatOpenAI

# %%
chat_llm = ChatOpenAI(model="gpt-4o-mini")

# %%
# I invoke to test if the LLM is working or not
chat_llm.invoke("Hello, how are you?").content
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 # I invoke to test if the LLM is working or not
# ----> 2 chat_llm.invoke("Hello, how are you?").content
#
# File ~/Documents/dupe/liveGAI/env/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
# ...

# %%
import os
import openai
 
openai.api_key = os.environ['ssk-proj-sqOVixs4_Cp6NiZSsmyflgWZzbAv86AXsCYoAzjZtP6MoCrvppeT3XvITBGVPG4N1z7NJ76NsmT3BlbkFJMOytTG5HYqaKffmVutJD3qpGaCplolkCxGCcXZ4YKMc6NoSenUs-tV8YgcAG-_8Lx055Y4D5gA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 4
#       1 import os
#       2 import openai
# ----> 4 openai.api_key = os.environ['ssk-proj-sqOVixs4_Cp6NiZSsmyflgWZzbAv86AXsCYoAzjZtP6MoCrvppeT3XvITBGVPG4N1z7NJ76NsmT3BlbkFJMOytTG5HYqaKffmVutJD3qpGaCplolkCxGCcXZ4YKMc6NoSenUs-tV8YgcAG-_8Lx055Y4D5gA']
#
# File <frozen os>:717, in __getitem__(self, key)
#
# KeyError: 'ssk-proj-sqOVixs4_Cp6NiZSsmyflgWZzbAv86AXsCYoAzjZtP6MoCrvppeT3XvITBGVPG4N1z7NJ76NsmT3BlbkFJMOytTG5HYqaKffmVutJD3qpGaCplolkCxGCcXZ4YKMc6NoSenUs-tV8YgcAG-_8Lx055Y4D5gA'
